# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import numpy as np
import os
from PIL import Image
import matplotlib.pyplot as plt

def load_quantum_state_data(image_folder_path, target_size=(128, 128)):
    """
    Load and preprocess quantum state images from the specified folder.
    Returns images and their corresponding principal quantum numbers (n).
    """
    images = []
    labels = []
    skipped_files = []
    
    for filename in os.listdir(image_folder_path):
        if filename.endswith('.png'):
            try:
                # Extract n from filename (format: n_l_m.png)
                n = int(filename.split('_')[0])
                
                # Load and preprocess image
                image_path = os.path.join(image_folder_path, filename)
                image = Image.open(image_path).convert('RGB')
                image = image.resize(target_size)
                images.append(np.array(image))
                labels.append(n)
                
            except (ValueError, IndexError):
                skipped_files.append(filename)
    
    print(f"Loaded {len(images)} images and {len(labels)} labels.")
    print(f"Skipped {len(skipped_files)} files due to naming convention issues.")
    print(f"Unique n values found: {np.unique(labels)}")
    
    return np.array(images), np.array(labels)

def create_cnn_model(input_shape, num_classes):
    """
    Create a simple CNN model for quantum state classification.
    """
    model = models.Sequential([
        # First Convolutional Block
        layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape),
        layers.MaxPooling2D((2, 2)),
        
        # Second Convolutional Block
        layers.Conv2D(64, (3, 3), activation='relu'),
        layers.MaxPooling2D((2, 2)),
        
        # Third Convolutional Block
        layers.Conv2D(64, (3, 3), activation='relu'),
        layers.MaxPooling2D((2, 2)),
        
        # Flatten and Dense Layers
        layers.Flatten(),
        layers.Dense(64, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation='softmax')
    ])
    
    return model

def train_model():
    # Load and preprocess data
    train_dir = 'training-data'  # Directory containing training images
    X_train, y_train = load_quantum_state_data(train_dir)
    
    # Data preprocessing
    X_train = X_train.astype('float32') / 255.0
    max_n = np.max(y_train)
    y_train = tf.keras.utils.to_categorical(y_train - 1, max_n)
    
    # Create and compile model
    model = create_cnn_model((128, 128, 3), max_n)
    model.compile(
        optimizer='adam',
        loss='categorical_crossentropy',
        metrics=['categorical_accuracy']
    )
    
    # Display model summary
    model.summary()
    
    # Train model
    history = model.fit(
        X_train, y_train,
        epochs=200,
        batch_size=16,
        validation_split=0.2
    )
    
    return model, history

def predict_quantum_state(model, image_path):
    """
    Predict the principal quantum number of a given quantum state image.
    """
    # Load and preprocess image
    image = Image.open(image_path).convert('RGB')
    image = image.resize((128, 128))
    image = np.array(image)
    image = image.astype('float32') / 255.0
    image = np.expand_dims(image, axis=0)
    
    # Make prediction
    prediction = model.predict(image)
    predicted_n = np.argmax(prediction) + 1
    
    return predicted_n

def main():
    # Train the model
    print("Training model...")
    model, history = train_model()
    
    # Test the model on a new image
    test_dir = 'classification-data'
    X_test, y_test = load_quantum_state_data(test_dir)
    
    # Preprocess test data
    X_test = X_test.astype('float32') / 255.0
    
    # Make predictions
    predictions = model.predict(X_test)
    predicted_n = np.argmax(predictions, axis=1) + 1
    
    print(f"Predicted principal quantum numbers (n): {predicted_n}")
    
if __name__ == "__main__":
    main()
# Out:
# Training model...
# Loaded 84 images and 84 labels.
# Skipped 0 files due to naming convention issues.
# Unique n values found: [1 2 3 4 5 6 7]
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 126, 126, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 63, 63, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 61, 61, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 30, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 28, 28, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 12544)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │       802,880 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │           455 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 859,655 (3.28 MB)
#  Trainable params: 859,655 (3.28 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - categorical_accuracy: 0.2441 - loss: 1.7678 - val_categorical_accuracy: 0.1765 - val_loss: 3.0438
# Epoch 2/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - categorical_accuracy: 0.3555 - loss: 1.4367 - val_categorical_accuracy: 0.1765 - val_loss: 2.2392
# Epoch 3/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - categorical_accuracy: 0.4054 - loss: 1.3840 - val_categorical_accuracy: 0.1765 - val_loss: 2.2095
# Epoch 4/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - categorical_accuracy: 0.3483 - loss: 1.2822 - val_categorical_accuracy: 0.1765 - val_loss: 1.9458
# Epoch 5/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - categorical_accuracy:
200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 157ms/step - categorical_accuracy: 1.0000 - loss: 0.0189 - val_categorical_accuracy: 0.4118 - val_loss: 8.9168
# Epoch 144/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 135ms/step - categorical_accuracy: 1.0000 - loss: 0.0135 - val_categorical_accuracy: 0.4118 - val_loss: 9.4679
# Epoch 145/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 137ms/step - categorical_accuracy: 0.9571 - loss: 0.0382 - val_categorical_accuracy: 0.4118 - val_loss: 9.7357
# Epoch 146/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - categorical_accuracy: 0.9837 - loss: 0.0809 - val_categorical_accuracy: 0.4118 - val_loss: 9.6623
# Epoch 147/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/step - categorical_accuracy: 0.9733 - loss: 0.0679 - val_categorical_accuracy: 0.4118 - val_loss: 9.6922
# Epoch 148/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 134ms/step - categorical_accuracy: 0.9466 - loss: 0.1392 - val_categorical_accuracy: 0.4118 - val_loss: 9.8810
# Epoch 149/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - categorical_accuracy: 1.0000 - loss: 0.0114 - val_categorical_accuracy: 0.4118 - val_loss: 10.0747
# Epoch 150/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 162ms/step - categorical_accuracy: 0.9733 - loss: 0.0657 - val_categorical_accuracy: 0.4118 - val_loss: 9.8377
# Epoch 151/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 139ms/step - categorical_accuracy: 1.0000 - loss: 0.0278 - val_categorical_accuracy: 0.4118 - val_loss: 9.9909
# Epoch 152/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/step - categorical_accuracy: 0.9814 - loss: 0.0698 - val_categorical_accuracy: 0.4118 - val_loss: 9.9613
# Epoch 153/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - categorical_accuracy: 0.9675 - loss: 0.0427 - val_categorical_accuracy: 0.4118 - val_loss: 9.7369
# Epoch 154/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 127ms/step - categorical_accuracy: 1.0000 - loss: 0.0049 - val_categorical_accuracy: 0.4118 - val_loss: 9.6367
# Epoch 155/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - categorical_accuracy: 0.9924 - loss: 0.0176 - val_categorical_accuracy: 0.4118 - val_loss: 9.6297
# Epoch 156/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - categorical_accuracy: 1.0000 - loss: 0.0034 - val_categorical_accuracy: 0.4118 - val_loss: 9.6647
# Epoch 157/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 130ms/step - categorical_accuracy: 0.9889 - loss: 0.0602 - val_categorical_accuracy: 0.4118 - val_loss: 9.6791
# Epoch 158/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - categorical_accuracy: 1.0000 - loss: 0.0061 - val_categorical_accuracy: 0.4118 - val_loss: 9.7617
# Epoch 159/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - categorical_accuracy: 0.9889 - loss: 0.0165 - val_categorical_accuracy: 0.4118 - val_loss: 9.8406
# Epoch 160/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - categorical_accuracy: 0.9889 - loss: 0.0214 - val_categorical_accuracy: 0.4118 - val_loss: 10.0399
# Epoch 161/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - categorical_accuracy: 0.9733 - loss: 0.0499 - val_categorical_accuracy: 0.4118 - val_loss: 10.0456
# Epoch 162/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 138ms/step - categorical_accuracy: 1.0000 - loss: 0.0086 - val_categorical_accuracy: 0.4118 - val_loss: 10.1280
# Epoch 163/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 123ms/step - categorical_accuracy: 1.0000 - loss: 0.0071 - val_categorical_accuracy: 0.4118 - val_loss: 10.2166
# Epoch 164/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 136ms/step - categorical_accuracy: 0.9889 - loss: 0.0445 - val_categorical_accuracy: 0.4118 - val_loss: 10.0939
# Epoch 165/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 130ms/step - categorical_accuracy: 0.9889 - loss: 0.0403 - val_categorical_accuracy: 0.4118 - val_loss: 10.0224
# Epoch 166/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - categorical_accuracy: 0.9924 - loss: 0.0174 - val_categorical_accuracy: 0.4118 - val_loss: 10.1910
# Epoch 167/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 127ms/step - categorical_accuracy: 0.9304 - loss: 0.1178 - val_categorical_accuracy: 0.4118 - val_loss: 10.4082
# Epoch 168/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - categorical_accuracy: 0.9837 - loss: 0.0660 - val_categorical_accuracy: 0.4118 - val_loss: 10.2826
# Epoch 169/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/step - categorical_accuracy: 0.9950 - loss: 0.0167 - val_categorical_accuracy: 0.4118 - val_loss: 10.2096
# Epoch 170/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - categorical_accuracy: 1.0000 - loss: 0.0096 - val_categorical_accuracy: 0.4118 - val_loss: 10.1823
# Epoch 171/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - categorical_accuracy: 0.9889 - loss: 0.0548 - val_categorical_accuracy: 0.4118 - val_loss: 9.9849
# Epoch 172/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - categorical_accuracy: 1.0000 - loss: 0.0037 - val_categorical_accuracy: 0.4118 - val_loss: 9.7777
# Epoch 173/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step - categorical_accuracy: 1.0000 - loss: 0.0125 - val_categorical_accuracy: 0.4118 - val_loss: 9.8103
# Epoch 174/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 159ms/step - categorical_accuracy: 1.0000 - loss: 9.5957e-04 - val_categorical_accuracy: 0.4118 - val_loss: 9.9379
# Epoch 175/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 134ms/step - categorical_accuracy: 0.9571 - loss: 0.0630 - val_categorical_accuracy: 0.4118 - val_loss: 9.4359
# Epoch 176/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 134ms/step - categorical_accuracy: 0.9837 - loss: 0.0562 - val_categorical_accuracy: 0.4118 - val_loss: 9.7642
# Epoch 177/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - categorical_accuracy: 1.0000 - loss: 0.0032 - val_categorical_accuracy: 0.4118 - val_loss: 10.0343
# Epoch 178/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 135ms/step - categorical_accuracy: 1.0000 - loss: 0.0044 - val_categorical_accuracy: 0.4118 - val_loss: 10.2892
# Epoch 179/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - categorical_accuracy: 0.9571 - loss: 0.1149 - val_categorical_accuracy: 0.4118 - val_loss: 10.1387
# Epoch 180/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 136ms/step - categorical_accuracy: 0.9657 - loss: 0.0556 - val_categorical_accuracy: 0.4118 - val_loss: 10.1358
# Epoch 181/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step - categorical_accuracy: 0.9889 - loss: 0.0222 - val_categorical_accuracy: 0.4118 - val_loss: 10.4182
# Epoch 182/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 136ms/step - categorical_accuracy: 1.0000 - loss: 0.0183 - val_categorical_accuracy: 0.4118 - val_loss: 10.7307
# Epoch 183/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - categorical_accuracy: 0.9889 - loss: 0.0175 - val_categorical_accuracy: 0.4118 - val_loss: 10.9480
# Epoch 184/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - categorical_accuracy: 1.0000 - loss: 0.0077 - val_categorical_accuracy: 0.4118 - val_loss: 11.2147
# Epoch 185/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - categorical_accuracy: 1.0000 - loss: 0.0057 - val_categorical_accuracy: 0.4118 - val_loss: 11.7514
# Epoch 186/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - categorical_accuracy: 0.9889 - loss: 0.0346 - val_categorical_accuracy: 0.4118 - val_loss: 12.0403
# Epoch 187/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - categorical_accuracy: 1.0000 - loss: 0.0080 - val_categorical_accuracy: 0.4118 - val_loss: 12.2852
# Epoch 188/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - categorical_accuracy: 0.9924 - loss: 0.0147 - val_categorical_accuracy: 0.4118 - val_loss: 12.4631
# Epoch 189/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 134ms/step - categorical_accuracy: 1.0000 - loss: 4.5628e-04 - val_categorical_accuracy: 0.4118 - val_loss: 12.5857
# Epoch 190/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - categorical_accuracy: 0.9837 - loss: 0.0336 - val_categorical_accuracy: 0.4118 - val_loss: 12.9417
# Epoch 191/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - categorical_accuracy: 1.0000 - loss: 0.0018 - val_categorical_accuracy: 0.4118 - val_loss: 13.2821
# Epoch 192/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 134ms/step - categorical_accuracy: 1.0000 - loss: 5.0224e-04 - val_categorical_accuracy: 0.4118 - val_loss: 13.5190
# Epoch 193/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - categorical_accuracy: 1.0000 - loss: 2.7902e-04 - val_categorical_accuracy: 0.4118 - val_loss: 13.7432
# Epoch 194/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 135ms/step - categorical_accuracy: 0.9733 - loss: 0.0424 - val_categorical_accuracy: 0.4118 - val_loss: 13.9232
# Epoch 195/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step - categorical_accuracy: 0.9837 - loss: 0.0359 - val_categorical_accuracy: 0.4118 - val_loss: 14.2363
# Epoch 196/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 130ms/step - categorical_accuracy: 1.0000 - loss: 3.6672e-04 - val_categorical_accuracy: 0.4118 - val_loss: 14.6419
# Epoch 197/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - categorical_accuracy: 0.9924 - loss: 0.0572 - val_categorical_accuracy: 0.4118 - val_loss: 14.9309
# Epoch 198/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 155ms/step - categorical_accuracy: 0.9733 - loss: 0.0467 - val_categorical_accuracy: 0.4118 - val_loss: 15.0020
# Epoch 199/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - categorical_accuracy: 1.0000 - loss: 0.0120 - val_categorical_accuracy: 0.4118 - val_loss: 15.1480
# Epoch 200/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 138ms/step - categorical_accuracy: 1.0000 - loss: 0.0219 - val_categorical_accuracy: 0.4118 - val_loss: 15.2465
# Loaded 1 images and 1 labels.
# Skipped 0 files due to naming convention issues.
# Unique n values found: [6]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# Predicted principal quantum numbers (n): [6]
